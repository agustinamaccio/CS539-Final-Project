# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import pandas as pd
files = os.listdir('/content/drive/MyDrive/CS539 Project/New Playlist Data')

# %%
col = ['playlist_name', 'user','danceability', 'energy',
       'key', 'loudness', 'mode', 'speechiness', 'instrumentalness',
       'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature']

columns = ['playlist_name', 'user']
for n in col[2:]:
  columns.append(n+'_var')
  columns.append(n+'_mean')
  columns.append(n+'_max')
  columns.append(n+'_min')
  

data = pd.DataFrame(columns = columns)


for file in files:
    df = pd.read_csv('/content/drive/MyDrive/CS539 Project/New Playlist Data/'+file)
    dict = {'playlist_name':df['playlist_name'].iloc[0], 'user':df['user'].iloc[0]}
    for i in col[2:]:
      Var = i+'_var'
      dict[Var] = df[i].var()
      Mean = i+'_mean'
      dict[Mean] = df[i].mean()
      Max = i+'_max'
      dict[Max] = max(df[i])
      Min = i+'_min'
      dict[Min] = min(df[i])
    data = data.append(dict, ignore_index=True)

# %%
data.head(10)
# Out:
#                         playlist_name              user  danceability_var  \
# 0      lumineers vibes and other bops              Uday          0.013940
# 1                               Vibes  Gabrielle Cabebe          0.013509
# 2                   This Is Metallica              Tess          0.020919
# 3  I should have been cast in step up              Tess          0.020307
# 4                           sad bitch              Tess          0.015632
# 5                      Ady's Playlist      Adityavikram          0.010372
# 6                            Rock Mix    Omkar Bharambe          0.014045
# 7                           Metal Mix    Omkar Bharambe          0.011288
# 8                           Hard Rock    Omkar Bharambe          0.010194
# 9                       Rock Classics    Omkar Bharambe          0.018576
#
#    danceability_mean  danceability_max  danceability_min  energy_var  \
# 0           0.585850             0.842             0.300    0.048796
# 1           0.633560             0.837             0.345    0.021441
# 2           0.432420             0.685             0.128    0.023727
# 3           0.711037             0.932             0.435    0.014000
# 4           0.507714             0.747             0.298    0.015489
# 5           0.613352             0.829             0.309    0.017039
# 6           0.469620             0.768             0.256    0.021991
# 7           0.383020             0.689             0.248    0.008460
# 8           0.467920             0.698             0.168    0.007268
# 9           0.512810             0.933             0.252    0.041947
#
#    energy_mean  energy_max  energy_min  ...  tempo_max  tempo_min  \
# 0     0.508563       0.936      0.0256  ...    205.660     76.023
# 1     0.546490       0.873      0.2170  ...    178.555     50.176
# 2     0.844340       0.991      0.2780  ...    203.790     86.634
# 3     0.693556       0.920      0.4540  ...    203.862     65.964
# 4     0.395964       0.619      0.1300  ...    185.972     66.165
# 5     0.701507       0.956      0.4350  ...    180.064     74.896
# 6     0.777060       0.978      0.3940  ...    203.006     79.588
# 7     0.891780       0.996      0.6580  ...    172.756     88.777
# 8     0.895000       0.989      0.5800  ...    198.093     75.005
# 9     0.729260       0.996      0.2010  ...    203.006     75.009
#
#   duration_ms_var duration_ms_mean  duration_ms_max  duration_ms_min  \
# 0    3.109683e+09    219369.590000           404467            50081
# 1    5.329000e+09    250225.860000           592920           133995
# 2    1.043761e+10    346598.280000           586507            86907
# 3    8.130932e+08    229748.222222           304600           192213
# 4    7.129790e+09    240187.892857           613027           152667
# 5    1.678615e+09    217668.816901           352173           148387
# 6    4.697211e+09    262301.960000           515387           140773
# 7    8.592428e+09    295495.960000           818693           153840
# 8    3.362933e+09    225970.620000           515387           125902
# 9    6.698399e+09    265027.280000           535733           121160
#
#    time_signature_var  time_signature_mean  time_signature_max  \
# 0            0.310606             3.850000                   5
# 1            0.065758             3.930000                   4
# 2            0.075102             3.920000                   4
# 3            0.037037             3.962963                   4
# 4            0.099206             3.892857                   4
# 5            0.028571             4.000000                   5
# 6            0.020000             3.980000                   4
# 7            0.020000             3.980000                   4
# 8            0.039184             3.960000                   4
# 9            0.010000             3.990000                   4
#
#    time_signature_min
# 0                   1
# 1                   3
# 2                   3
# 3                   3
# 4                   3
# 5                   3
# 6                   3
# 7                   3
# 8                   3
# 9                   3
#
# [10 rows x 50 columns]

# %%
data.to_csv('/content/drive/MyDrive/CS539 Project/newdata.csv', index = False)
